# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ##### Load data

# %%
# read data from file
data = pd.read_csv('./data/house_data.csv')
#data.head()

# %% [markdown]
# ##### Select only data for 'Type' 'Rækkehus'

# %%
data = data[data['Type'] == 'Rækkehus']

# %% [markdown]
# ##### Before dropping columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1643 entries, 36 to 38548
# Data columns (total 45 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   URL                          1643 non-null   object
#  1   Adresse                      1643 non-null   object
#  2   Year build                   1643 non-null   object
#  3   Pris                         1643 non-null   object
#  4   Type                         1643 non-null   object
#  5   Energimærke                  1551 non-null   object
#  6   Ejerudgift                   1643 non-null   object
#  7   Boligydelse                  0 non-null      object
#  8   Anvendelse                   1643 non-null   object
#  9   Boligtype                    1643 non-null   object
#  10  Enhedsareal                  1643 non-null   object
#  11  Beboelsesareal               1643 non-null   object
#  12  Værelser                     1643 non-null   float64
#  13  Antal toiletter              1643 non-null   float64
#  14  Badeforhold                  1640 non-null   object
#  15  Antal badeværelser           1643 non-null   float64
#  16  Køkkenforhold                1640 non-null   object
#  17  Energikode                   841 non-null    object
#  18  Toiletforhold                1640 non-null   object
#  19  Bygningsnummer               1643 non-null   float64
#  20  Ydervæg                      1643 non-null   object
#  21  Tag                          1643 non-null   object
#  22  Etager                       1643 non-null   float64
#  23  Carport                      1643 non-null   float64
#  24  Seneste ombygning            1643 non-null   float64
#  25  Udhus                        1643 non-null   float64
#  26  Boligstørrelse BBR           1643 non-null   float64
#  27  Objekt status                1643 non-null   object
#  28  Boligstørrelse tinglyst      1643 non-null   float64
#  29  Afvigende etager             1643 non-null   object
#  30  Boligstørrelse               1643 non-null   float64
#  31  Boligenhed med eget køkken   1643 non-null   float64
#  32  Varmeinstallation            1643 non-null   object
#  33  Boligenhed uden eget køkken  1643 non-null   float64
#  34  Matrikelnummer               1448 non-null   object
#  35  Kommunal ejerlav navn        1448 non-null   object
#  36  Grundstørrelse               1448 non-null   float64
#  37  Lands ejerlav kode           1448 non-null   float64
#  38  Vejareal                     1448 non-null   float64
#  39  Lands ejerlav navn           1448 non-null   object
#  40  Primær matrikel              1448 non-null   object
#  41  Ejendomsnummer               1643 non-null   float64
#  42  Kommunal ejerlav kode        1448 non-null   float64
#  43  Ejendomsværdiskat            1643 non-null   float64
#  44  Grundskyld                   1643 non-null   float64
# dtypes: float64(20), object(25)
# memory usage: 590.5+ KB

# %% [markdown]
# ##### Drop non-relevant columns (incl. Type +  Boligydelse)

# %%
data.drop([
    'Vejareal',
    'Lands ejerlav kode',
    'Kommunal ejerlav kode',
    'Ejendomsnummer',
    'Primær matrikel',
    'Lands ejerlav navn',
    'Kommunal ejerlav navn',
    'Matrikelnummer',
    'Afvigende etager',
    'Boligstørrelse tinglyst',
    'Objekt status',
    'Boligstørrelse BBR',
    'Bygningsnummer',
    'Beboelsesareal',
    'URL',
    'Boligydelse',
    'Anvendelse',
    'Type',
    'Boligstørrelse'
], 'columns', inplace=True)

# %% [markdown]
# ##### Missing values

# %%
sb.set(font_scale=1)
data_null = data.isna().sum()
plt.figure(figsize=(8,8))
data_null[data_null!=0].plot(kind='barh');

# %%
# drop columns if lot of missing values
data.drop(['Energikode'], 'columns', inplace=True)

# %%
# Find missing values in the data and drop those rows:
print('rows before drop n/a',len(data))
bool_matrix = data.isnull() # dataframe with True and False values for each cell in the villa_data
only_null_filter = bool_matrix.any(axis=1) # is there a True value in any column in each row. returns a pandas Series with index matching index of villa dataframe
missing = data[only_null_filter] # show all rows that has one or more null values
data = data.dropna()
print('rows after',len(data))
#pd.options.display.max_rows = None # let me see all rows in the dataframe (can be used with columns too)
#villa_data
#bool_matrix
# Out:
# rows before drop n/a 1643
# rows after 1357

# %% [markdown]
# ##### After dropping columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1357 entries, 36 to 38500
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Adresse                      1357 non-null   object
#  1   Year build                   1357 non-null   object
#  2   Pris                         1357 non-null   object
#  3   Energimærke                  1357 non-null   object
#  4   Ejerudgift                   1357 non-null   object
#  5   Boligtype                    1357 non-null   object
#  6   Enhedsareal                  1357 non-null   object
#  7   Værelser                     1357 non-null   float64
#  8   Antal toiletter              1357 non-null   float64
#  9   Badeforhold                  1357 non-null   object
#  10  Antal badeværelser           1357 non-null   float64
#  11  Køkkenforhold                1357 non-null   object
#  12  Toiletforhold                1357 non-null   object
#  13  Ydervæg                      1357 non-null   object
#  14  Tag                          1357 non-null   object
#  15  Etager                       1357 non-null   float64
#  16  Carport                      1357 non-null   float64
#  17  Seneste ombygning            1357 non-null   float64
#  18  Udhus                        1357 non-null   float64
#  19  Boligenhed med eget køkken   1357 non-null   float64
#  20  Varmeinstallation            1357 non-null   object
#  21  Boligenhed uden eget køkken  1357 non-null   float64
#  22  Grundstørrelse               1357 non-null   float64
#  23  Ejendomsværdiskat            1357 non-null   float64
#  24  Grundskyld                   1357 non-null   float64
# dtypes: float64(12), object(13)
# memory usage: 275.6+ KB

# %% [markdown]
# ##### Format values

# %%
# Address to zipcode
data['Adresse'] = data['Adresse'].str.extract(r'(\d{4})').astype('int')

# %%
# Year build
data['Year build'] = data['Year build'].astype('int')

# %%
# Pris
data['Pris'] = data['Pris'].astype('float')

# %%
# Ejerudgift
data['Ejerudgift'] = data['Ejerudgift'].astype('float')

# %%
# Enhedsareal
data['Enhedsareal'] = data['Enhedsareal'].astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1357 entries, 36 to 38500
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Adresse                      1357 non-null   int32
#  1   Year build                   1357 non-null   int32
#  2   Pris                         1357 non-null   float64
#  3   Energimærke                  1357 non-null   object
#  4   Ejerudgift                   1357 non-null   float64
#  5   Boligtype                    1357 non-null   object
#  6   Enhedsareal                  1357 non-null   float64
#  7   Værelser                     1357 non-null   float64
#  8   Antal toiletter              1357 non-null   float64
#  9   Badeforhold                  1357 non-null   object
#  10  Antal badeværelser           1357 non-null   float64
#  11  Køkkenforhold                1357 non-null   object
#  12  Toiletforhold                1357 non-null   object
#  13  Ydervæg                      1357 non-null   object
#  14  Tag                          1357 non-null   object
#  15  Etager                       1357 non-null   float64
#  16  Carport                      1357 non-null   float64
#  17  Seneste ombygning            1357 non-null   float64
#  18  Udhus                        1357 non-null   float64
#  19  Boligenhed med eget køkken   1357 non-null   float64
#  20  Varmeinstallation            1357 non-null   object
#  21  Boligenhed uden eget køkken  1357 non-null   float64
#  22  Grundstørrelse               1357 non-null   float64
#  23  Ejendomsværdiskat            1357 non-null   float64
#  24  Grundskyld                   1357 non-null   float64
# dtypes: float64(15), int32(2), object(8)
# memory usage: 265.0+ KB

# %% [markdown]
# ##### Numerical data

# %%
data.describe(percentiles=[0.1,0.25,0.5,0.75,0.9])
# Out:
#            Adresse   Year build          Pris    Ejerudgift  Enhedsareal  \
# count  1357.000000  1357.000000  1.357000e+03   1357.000000  1357.000000
# mean   5524.044215  1963.313191  2.595030e+06   2674.937362   115.337509
# std    2430.994482    90.194561  1.775964e+06   1210.887098    30.869807
# min    1432.000000     0.000000  9.900000e+04      0.000000     0.000000
# 10%    2660.000000  1897.000000  8.500000e+05   1358.000000    82.000000
# 25%    3100.000000  1949.000000  1.450000e+06   1804.000000    96.000000
# 50%    5000.000000  1977.000000  2.298000e+06   2463.000000   112.000000
# 75%    8240.000000  2006.000000  3.295000e+06   3361.000000   130.000000
# 90%    8920.000000  2018.000000  4.295000e+06   4141.000000   149.000000
# max    9900.000000  2021.000000  1.850000e+07  10116.000000   350.000000
#
#           Værelser  Antal toiletter  Antal badeværelser       Etager  \
# count  1357.000000      1357.000000         1357.000000  1357.000000
# mean      4.125276         1.490789            1.231393     1.312454
# std       1.070075         0.545250            0.461930     0.509149
# min       1.000000         1.000000            0.000000     1.000000
# 10%       3.000000         1.000000            1.000000     1.000000
# 25%       4.000000         1.000000            1.000000     1.000000
# 50%       4.000000         1.000000            1.000000     1.000000
# 75%       5.000000         2.000000            1.000000     2.000000
# 90%       5.000000         2.000000            2.000000     2.000000
# max      11.000000         3.000000            4.000000     4.000000
#
#            Carport  Seneste ombygning        Udhus  \
# count  1357.000000        1357.000000  1357.000000
# mean      0.691231         368.361828     0.550479
# std       4.212604         771.687959     3.681432
# min       0.000000           0.000000     0.000000
# 10%       0.000000           0.000000     0.000000
# 25%       0.000000           0.000000     0.000000
# 50%       0.000000           0.000000     0.000000
# 75%       0.000000           0.000000     0.000000
# 90%       0.000000        1982.400000     0.000000
# max      48.000000        2020.000000   100.000000
#
#        Boligenhed med eget køkken  Boligenhed uden eget køkken  \
# count                 1357.000000                  1357.000000
# mean                     1.025792                     0.001474
# std                      0.206989                     0.038376
# min                      1.000000                     0.000000
# 10%                      1.000000                     0.000000
# 25%                      1.000000                     0.000000
# 50%                      1.000000                     0.000000
# 75%                      1.000000                     0.000000
# 90%                      1.000000                     0.000000
# max                      5.000000                     1.000000
#
#        Grundstørrelse  Ejendomsværdiskat    Grundskyld
# count     1357.000000        1357.000000   1357.000000
# mean       431.226971        9956.271923   9914.344141
# std       1667.158982        5953.361724   8572.961217
# min          0.000000           0.000000      0.000000
# 10%        107.200000        2835.000000   1115.000000
# 25%        159.000000        6300.000000   4468.000000
# 50%        243.000000        9870.000000   7810.000000
# 75%        381.000000       13500.000000  13920.000000
# 90%        550.000000       16800.000000  20221.200000
# max      33917.000000       71500.000000  79312.000000

# %%
#pick out features, which have one dominant value in the whole sample
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15,10))
sb.set(font_scale=2)

data['Værelser'].hist(ax=axes[0,0])
axes[0,0].set_title('Værelser')

data['Antal toiletter'].hist(ax=axes[0,1])
axes[0,1].set_title('Antal toiletter')

data['Antal badeværelser'].hist(ax=axes[0,2])
axes[0,2].set_title('Antal badeværelser')

data['Etager'].hist(ax=axes[1,0])
axes[1,0].set_title('Etager')

data['Carport'].hist(ax=axes[1,1])
axes[1,1].set_title('Carport')

data['Seneste ombygning'].hist(ax=axes[1,2])
axes[1,2].set_title('Seneste ombygning')

data['Udhus'].hist(ax=axes[2,0])
axes[2,0].set_title('Udhus')

data['Boligenhed med eget køkken'].hist(ax=axes[2,1])
axes[2,1].set_title('Boligenhed med eget køkken')

data['Boligenhed uden eget køkken'].hist(ax=axes[2,2])
axes[2,2].set_title('Boligenhed uden eget køkken')

plt.tight_layout()

# drop features
data.drop([
    'Carport',
    'Udhus',
    'Boligenhed med eget køkken',
    'Boligenhed uden eget køkken'
], 'columns', inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1357 entries, 36 to 38500
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Adresse             1357 non-null   int32
#  1   Year build          1357 non-null   int32
#  2   Pris                1357 non-null   float64
#  3   Energimærke         1357 non-null   object
#  4   Ejerudgift          1357 non-null   float64
#  5   Boligtype           1357 non-null   object
#  6   Enhedsareal         1357 non-null   float64
#  7   Værelser            1357 non-null   float64
#  8   Antal toiletter     1357 non-null   float64
#  9   Badeforhold         1357 non-null   object
#  10  Antal badeværelser  1357 non-null   float64
#  11  Køkkenforhold       1357 non-null   object
#  12  Toiletforhold       1357 non-null   object
#  13  Ydervæg             1357 non-null   object
#  14  Tag                 1357 non-null   object
#  15  Etager              1357 non-null   float64
#  16  Seneste ombygning   1357 non-null   float64
#  17  Varmeinstallation   1357 non-null   object
#  18  Grundstørrelse      1357 non-null   float64
#  19  Ejendomsværdiskat   1357 non-null   float64
#  20  Grundskyld          1357 non-null   float64
# dtypes: float64(11), int32(2), object(8)
# memory usage: 222.6+ KB

# %% [markdown]
# ##### Abnormal feature values - before

# %%
fig, axes = plt.subplots(nrows=7, ncols=2, figsize=(30,30))
sb.set(font_scale=2)

data['Enhedsareal'].hist(ax=axes[0,0], bins=40);
axes[0,0].set_title('Enhedsareal')
sb.boxplot(ax=axes[0,1], x=data['Enhedsareal'])
axes[0,1].set_title('Enhedsareal')

data['Værelser'].hist(ax=axes[1,0], bins=40);
axes[1,0].set_title('Værelser')
sb.boxplot(ax=axes[1,1], x=data['Værelser'])
axes[1,1].set_title('Værelser')

data['Antal toiletter'].hist(ax=axes[2,0], bins=40);
axes[2,0].set_title('Antal toiletter')
sb.boxplot(ax=axes[2,1], x=data['Antal toiletter'])
axes[2,1].set_title('Antal toiletter')

data['Antal badeværelser'].hist(ax=axes[3,0], bins=40);
axes[3,0].set_title('Antal badeværelser')
sb.boxplot(ax=axes[3,1], x=data['Antal badeværelser'])
axes[3,1].set_title('Antal badeværelser')

data['Grundstørrelse'].hist(ax=axes[4,0], bins=40);
axes[4,0].set_title('Grundstørrelse')
sb.boxplot(ax=axes[4,1], x=data['Grundstørrelse'])
axes[4,1].set_title('Grundstørrelse')

data['Year build'].hist(ax=axes[5,0], bins=40);
axes[5,0].set_title('Year build')
sb.boxplot(ax=axes[5,1], x=data['Year build'])
axes[5,1].set_title('Year build')

data['Seneste ombygning'].hist(ax=axes[6,0], bins=40);
axes[6,0].set_title('Seneste ombygning')
sb.boxplot(ax=axes[6,1], x=data['Seneste ombygning'])
axes[6,1].set_title('Seneste ombygning')

plt.tight_layout()

# %%
# drop abnormal feature values
print(pd.value_counts(data['Enhedsareal']<180))
data = data[data['Enhedsareal']<180]

print(pd.value_counts(data['Værelser']<7))
data = data[data['Værelser']<7]

print(pd.value_counts(data['Antal toiletter']<=3))
data = data[data['Antal toiletter']<=3]

print(pd.value_counts(data['Antal badeværelser']<=3))
data = data[data['Antal badeværelser']<=3]

print(pd.value_counts(data['Grundstørrelse']<700))
data = data[data['Grundstørrelse']<700]

print(pd.value_counts( (data['Year build']>1900) & (data['Year build']<2020) ))
data = data[ (data['Year build']>1900) & (data['Year build']<2020) ]
# Out:
# True     1310
# False      47
# Name: Enhedsareal, dtype: int64
# True     1294
# False      16
# Name: Værelser, dtype: int64
# True    1294
# Name: Antal toiletter, dtype: int64
# True    1294
# Name: Antal badeværelser, dtype: int64
# True     1226
# False      68
# Name: Grundstørrelse, dtype: int64
# True     1013
# False     213
# Name: Year build, dtype: int64

# %% [markdown]
# ##### Format abnormal data

# %%
print(pd.value_counts ((data['Seneste ombygning']<1900)))
data['Seneste ombygning'] = np.where(data['Seneste ombygning'] < 1900, data['Year build'], data['Seneste ombygning'])
# Out:
# True     883
# False    130
# Name: Seneste ombygning, dtype: int64

# %% [markdown]
# ##### Abnormal feature values - after

# %%
fig, axes = plt.subplots(nrows=7, ncols=2, figsize=(30,30))
sb.set(font_scale=2)

data['Enhedsareal'].hist(ax=axes[0,0], bins=40);
axes[0,0].set_title('Enhedsareal')
sb.boxplot(ax=axes[0,1], x=data['Enhedsareal'])
axes[0,1].set_title('Enhedsareal')

data['Værelser'].hist(ax=axes[1,0], bins=40);
axes[1,0].set_title('Værelser')
sb.boxplot(ax=axes[1,1], x=data['Værelser'])
axes[1,1].set_title('Værelser')

data['Antal toiletter'].hist(ax=axes[2,0], bins=40);
axes[2,0].set_title('Antal toiletter')
sb.boxplot(ax=axes[2,1], x=data['Antal toiletter'])
axes[2,1].set_title('Antal toiletter')

data['Antal badeværelser'].hist(ax=axes[3,0], bins=40);
axes[3,0].set_title('Antal badeværelser')
sb.boxplot(ax=axes[3,1], x=data['Antal badeværelser'])
axes[3,1].set_title('Antal badeværelser')

data['Grundstørrelse'].hist(ax=axes[4,0], bins=40);
axes[4,0].set_title('Grundstørrelse')
sb.boxplot(ax=axes[4,1], x=data['Grundstørrelse'])
axes[4,1].set_title('Grundstørrelse')

data['Year build'].hist(ax=axes[5,0], bins=40);
axes[5,0].set_title('Year build')
sb.boxplot(ax=axes[5,1], x=data['Year build'])
axes[5,1].set_title('Year build')

data['Seneste ombygning'].hist(ax=axes[6,0], bins=40);
axes[6,0].set_title('Seneste ombygning')
sb.boxplot(ax=axes[6,1], x=data['Seneste ombygning'])
axes[6,1].set_title('Seneste ombygning')

plt.tight_layout()

# %% [markdown]
# ##### Categorical features

# %%
pd.set_option('display.max_columns', 40)
data.describe(include='all')
# Out:
#             Adresse   Year build          Pris Energimærke   Ejerudgift  \
# count   1013.000000  1013.000000  1.013000e+03        1013  1013.000000
# unique          NaN          NaN           NaN          13          NaN
# top             NaN          NaN           NaN           C          NaN
# freq            NaN          NaN           NaN         363          NaN
# mean    5345.802567  1978.129319  2.616524e+06         NaN  2718.073050
# std     2482.330263    29.123766  1.468624e+06         NaN  1102.783191
# min     1432.000000  1901.000000  9.900000e+04         NaN   691.000000
# 25%     2880.000000  1964.000000  1.645000e+06         NaN  1928.000000
# 50%     4681.000000  1979.000000  2.448000e+06         NaN  2551.000000
# 75%     8230.000000  2004.000000  3.295000e+06         NaN  3370.000000
# max     9900.000000  2019.000000  1.399500e+07         NaN  9378.000000
#
#                                                 Boligtype  Enhedsareal  \
# count                                                1013  1013.000000
# unique                                                  1          NaN
# top     Egentlig beboelseslejlighed boligenhed med ege...          NaN
# freq                                                 1013          NaN
# mean                                                  NaN   111.094768
# std                                                   NaN    22.467871
# min                                                   NaN    52.000000
# 25%                                                   NaN    96.000000
# 50%                                                   NaN   110.000000
# 75%                                                   NaN   127.000000
# max                                                   NaN   178.000000
#
#            Værelser  Antal toiletter            Badeforhold  \
# count   1013.000000      1013.000000                   1013
# unique          NaN              NaN                      2
# top             NaN              NaN  Badeværelse i enheden
# freq            NaN              NaN                   1011
# mean       4.005923         1.489635                    NaN
# std        0.858556         0.523311                    NaN
# min        1.000000         1.000000                    NaN
# 25%        3.000000         1.000000                    NaN
# 50%        4.000000         1.000000                    NaN
# 75%        4.000000         2.000000                    NaN
# max        6.000000         3.000000                    NaN
#
#         Antal badeværelser          Køkkenforhold  \
# count          1013.000000                   1013
# unique                 NaN                      1
# top                    NaN  Eget køkken med afløb
# freq                   NaN                   1013
# mean              1.209279                    NaN
# std               0.418959                    NaN
# min               0.000000                    NaN
# 25%               1.000000                    NaN
# 50%               1.000000                    NaN
# 75%               1.000000                    NaN
# max               3.000000                    NaN
#
#                          Toiletforhold  Ydervæg                          Tag  \
# count                             1013     1013                         1013
# unique                               1        8                            9
# top     Vandskyllende toilet i enheden  Mursten  Fibercement herunder asbest
# freq                              1013      878                          271
# mean                               NaN      NaN                          NaN
# std                                NaN      NaN                          NaN
# min                                NaN      NaN                          NaN
# 25%                                NaN      NaN                          NaN
# 50%                                NaN      NaN                          NaN
# 75%                                NaN      NaN                          NaN
# max                                NaN      NaN                          NaN
#
#              Etager  Seneste ombygning     Varmeinstallation  Grundstørrelse  \
# count   1013.000000        1013.000000                  1013     1013.000000
# unique          NaN                NaN                     6             NaN
# top             NaN                NaN  Fjernvarme blokvarme             NaN
# freq            NaN                NaN                   689             NaN
# mean       1.333662        1982.951629                   NaN      264.211254
# std        0.517693          25.543821                   NaN      143.332530
# min        1.000000        1902.000000                   NaN        0.000000
# 25%        1.000000        1970.000000                   NaN      161.000000
# 50%        1.000000        1981.000000                   NaN      231.000000
# 75%        2.000000        2006.000000                   NaN      354.000000
# max        4.000000        2020.000000                   NaN      689.000000
#
#         Ejendomsværdiskat    Grundskyld
# count         1013.000000   1013.000000
# unique                NaN           NaN
# top                   NaN           NaN
# freq                  NaN           NaN
# mean         11000.013820  10989.628825
# std           4808.667951   7859.597881
# min              0.000000      0.000000
# 25%           7665.000000   5891.000000
# 50%          10500.000000   9102.000000
# 75%          13650.000000  14573.000000
# max          30550.000000  79312.000000

# %%
sb.set()
lst_out = ['Energimærke', 'Boligtype', 'Badeforhold',
           'Køkkenforhold', 'Toiletforhold',
           'Ydervæg', 'Tag', 'Varmeinstallation']
sb.set(font_scale=2)
n_row = 3
n_col = 3
fig, axes = plt.subplots(nrows=n_row, ncols=n_col, figsize=(50,30))
for i in enumerate(lst_out):
    pd.value_counts(data[i[1]]).plot(kind='barh',ax=axes[i[0]//n_row,i[0]%n_col])
    axes[i[0]//n_row,i[0]%n_col].set_title(i[1]);
plt.tight_layout()

# drop features
data.drop([
    'Boligtype',
    'Badeforhold',
    'Køkkenforhold',
    'Toiletforhold'
], 'columns', inplace=True)

# %%
sb.set(font_scale=1)
plt.figure(figsize=(10,10))
data.corr()['Pris'].plot(kind='barh');

# %% [markdown]
# ##### Find unique values for categorical features

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1013 entries, 136 to 38003
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Adresse             1013 non-null   int32
#  1   Year build          1013 non-null   int32
#  2   Pris                1013 non-null   float64
#  3   Energimærke         1013 non-null   object
#  4   Ejerudgift          1013 non-null   float64
#  5   Enhedsareal         1013 non-null   float64
#  6   Værelser            1013 non-null   float64
#  7   Antal toiletter     1013 non-null   float64
#  8   Antal badeværelser  1013 non-null   float64
#  9   Ydervæg             1013 non-null   object
#  10  Tag                 1013 non-null   object
#  11  Etager              1013 non-null   float64
#  12  Seneste ombygning   1013 non-null   float64
#  13  Varmeinstallation   1013 non-null   object
#  14  Grundstørrelse      1013 non-null   float64
#  15  Ejendomsværdiskat   1013 non-null   float64
#  16  Grundskyld          1013 non-null   float64
# dtypes: float64(11), int32(2), object(4)
# memory usage: 134.5+ KB

# %%
# Energimærke
print('Energimærke')
print(data.Energimærke.unique())

# Ydervæg
print('Ydervæg')
print(data.Ydervæg.unique())

# Tag
print('Tag')
print(data.Tag.unique())

# Varmeinstallation
print('Varmeinstallation')
print(data.Varmeinstallation.unique())
# Out:
# Energimærke
# ['A10' 'B' 'C' 'D' 'E' 'A15' 'F' 'G' 'A20' 'A2' 'A' 'A1' '0']
# Ydervæg
# ['Fibercement herunder asbest' 'Mursten' 'Fibercement uden asbest'
#  'Betonelementer' 'Andet materiale' 'Træ' 'Letbetonsten' 'Glas']
# Tag
# ['Tagpap med lille hældning' 'Tagpap med stor hældning' 'Betontagsten'
#  'Tegl' 'Fibercement herunder asbest' 'Metal' 'Fibercement uden asbest'
#  'Levende tage' 'Andet materiale']
# Varmeinstallation
# ['Fjernvarme blokvarme' 'Centralvarme med én fyringsenhed' 'Elvarme'
#  'Centralvarme med to fyringsenheder' 'Varmepumpe'
#  'Ovn til fast og flydende brændsel']

# %% [markdown]
# ##### Format and clean up categorical features

# %%
# remove data with Energimærke '0'
data = data[data.Energimærke != '0']

# %% [markdown]
# ##### Target - before

# %%
fig = plt.figure(figsize=(50,20))
sb.set(font_scale=2)
ax1 = fig.add_subplot(2,3,1)
ax1.set_title('Most popular apps')
ax1.ticklabel_format(style='plain')
data['Pris'].hist(bins=40);

ax2 = fig.add_subplot(2,3,2)
ax2.set_title('All apps)')
ax2.ticklabel_format(style='plain')
sb.boxplot(x=data['Pris'])
plt.tight_layout()

# %%
# drop data with abnormal target value
print(pd.value_counts(data['Pris']<6000000))
data = data[data['Pris']<6000000]
#target_val = data_new['SalePrice'].values
# Out:
# True     986
# False     26
# Name: Pris, dtype: int64

# %% [markdown]
# ##### Target - after

# %%
fig = plt.figure(figsize=(50,20))
sb.set(font_scale=2)
ax1 = fig.add_subplot(2,3,1)
ax1.set_title('Most popular apps (Data lingo?)')
ax1.ticklabel_format(style='plain')
data['Pris'].hist(bins=40);

ax2 = fig.add_subplot(2,3,2)
ax2.set_title('All apps (Data lingo?)')
ax2.ticklabel_format(style='plain')
sb.boxplot(x=data['Pris'])
plt.tight_layout()

# %%
data.describe(include='all')
# Out:
#             Adresse   Year build          Pris Energimærke   Ejerudgift  \
# count    986.000000   986.000000  9.860000e+02         986   986.000000
# unique          NaN          NaN           NaN          12          NaN
# top             NaN          NaN           NaN           C          NaN
# freq            NaN          NaN           NaN         357          NaN
# mean    5401.442191  1977.872211  2.477690e+06         NaN  2641.545639
# std     2466.459210    28.991473  1.163808e+06         NaN   960.275271
# min     2300.000000  1901.000000  9.900000e+04         NaN   691.000000
# 25%     2970.000000  1964.250000  1.595750e+06         NaN  1918.500000
# 50%     4700.000000  1978.500000  2.395000e+06         NaN  2502.000000
# 75%     8240.000000  2004.000000  3.195000e+06         NaN  3326.500000
# max     9900.000000  2019.000000  5.998000e+06         NaN  8196.000000
#
#         Enhedsareal    Værelser  Antal toiletter  Antal badeværelser  Ydervæg  \
# count    986.000000  986.000000       986.000000          986.000000      986
# unique          NaN         NaN              NaN                 NaN        7
# top             NaN         NaN              NaN                 NaN  Mursten
# freq            NaN         NaN              NaN                 NaN      859
# mean     110.410751    3.990872         1.475659            1.198783      NaN
# std       22.141461    0.851942         0.517624            0.411804      NaN
# min       52.000000    1.000000         1.000000            0.000000      NaN
# 25%       95.000000    3.000000         1.000000            1.000000      NaN
# 50%      110.000000    4.000000         1.000000            1.000000      NaN
# 75%      126.000000    4.000000         2.000000            1.000000      NaN
# max      176.000000    6.000000         3.000000            3.000000      NaN
#
#                                 Tag      Etager  Seneste ombygning  \
# count                           986  986.000000         986.000000
# unique                            9         NaN                NaN
# top     Fibercement herunder asbest         NaN                NaN
# freq                            270         NaN                NaN
# mean                            NaN    1.317444        1982.688641
# std                             NaN    0.493244          25.322918
# min                             NaN    1.000000        1902.000000
# 25%                             NaN    1.000000        1970.000000
# 50%                             NaN    1.000000        1981.000000
# 75%                             NaN    2.000000        2006.000000
# max                             NaN    3.000000        2019.000000
#
#            Varmeinstallation  Grundstørrelse  Ejendomsværdiskat    Grundskyld
# count                    986      986.000000         986.000000    986.000000
# unique                     6             NaN                NaN           NaN
# top     Fjernvarme blokvarme             NaN                NaN           NaN
# freq                     670             NaN                NaN           NaN
# mean                     NaN      264.894523       10716.995943  10394.433063
# std                      NaN      142.043466        4465.812045   6353.659866
# min                      NaN        0.000000           0.000000      0.000000
# 25%                      NaN      163.000000        7600.000000   5750.500000
# 50%                      NaN      231.000000       10500.000000   8966.000000
# 75%                      NaN      353.750000       13650.000000  14293.750000
# max                      NaN      689.000000       29400.000000  33598.000000

# %% [markdown]
# ##### Split data to numeric and categorical

# %%
numer = set(data.corr()['Pris'].index)
categ = list(set(data.columns) - set(data.corr()['Pris'].index))

# %%
numer
# Out:
# {'Adresse',
#  'Antal badeværelser',
#  'Antal toiletter',
#  'Ejendomsværdiskat',
#  'Ejerudgift',
#  'Enhedsareal',
#  'Etager',
#  'Grundskyld',
#  'Grundstørrelse',
#  'Pris',
#  'Seneste ombygning',
#  'Værelser',
#  'Year build'}

# %%
categ
# Out:
# ['Energimærke', 'Ydervæg', 'Tag', 'Varmeinstallation']

# %%
sb.set()
n_row = 2
n_col = 2
fig, axes = plt.subplots(nrows=n_row, ncols=n_col, figsize=(20,20))
sb.set(font_scale=2)
for i in enumerate(categ):
    pd.value_counts(data[i[1]]).plot(kind='barh',ax=axes[i[0]//n_row,i[0]%n_col])
    axes[i[0]//n_row,i[0]%n_col].set_title(i[1]);
plt.tight_layout()

# %%
# bring categories into a numerical format:
for i in categ:
    data[i] = data[i].factorize()[0]
data.head()
# Out:
#      Adresse  Year build       Pris  Energimærke  Ejerudgift  Enhedsareal  \
# 136     8361        1978  1798000.0            0      2296.0        104.0
# 159     4200        2008  2095000.0            1      1677.0        100.0
# 173     8260        1984  2268000.0            0      2376.0         82.0
# 178     2630        1967  2425000.0            2      2822.0         82.0
# 205     2640        1986  2795000.0            2      3027.0        120.0
#
#      Værelser  Antal toiletter  Antal badeværelser  Ydervæg  Tag  Etager  \
# 136       4.0              2.0                 1.0        0    0     2.0
# 159       3.0              2.0                 1.0        1    1     2.0
# 173       4.0              1.0                 1.0        1    2     3.0
# 178       4.0              1.0                 1.0        1    3     1.0
# 205       4.0              2.0                 1.0        1    2     1.0
#
#      Seneste ombygning  Varmeinstallation  Grundstørrelse  Ejendomsværdiskat  \
# 136             1978.0                  0           124.0             8000.0
# 159             2008.0                  0            77.0             9660.0
# 173             1984.0                  0           170.0             9555.0
# 178             1967.0                  0           196.0            10500.0
# 205             1986.0                  1           328.0            14000.0
#
#      Grundskyld
# 136      7750.0
# 159      1204.0
# 173     11624.0
# 178     12322.0
# 205     12076.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 986 entries, 136 to 38003
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Adresse             986 non-null    int32
#  1   Year build          986 non-null    int32
#  2   Pris                986 non-null    float64
#  3   Energimærke         986 non-null    int64
#  4   Ejerudgift          986 non-null    float64
#  5   Enhedsareal         986 non-null    float64
#  6   Værelser            986 non-null    float64
#  7   Antal toiletter     986 non-null    float64
#  8   Antal badeværelser  986 non-null    float64
#  9   Ydervæg             986 non-null    int64
#  10  Tag                 986 non-null    int64
#  11  Etager              986 non-null    float64
#  12  Seneste ombygning   986 non-null    float64
#  13  Varmeinstallation   986 non-null    int64
#  14  Grundstørrelse      986 non-null    float64
#  15  Ejendomsværdiskat   986 non-null    float64
#  16  Grundskyld          986 non-null    float64
# dtypes: float64(11), int32(2), int64(4)
# memory usage: 131.0 KB

# %%
plt.figure(figsize=(25,20))
sb.set(font_scale=1)
sb.heatmap(data.corr(),annot=True);

# %%
# dropping most correlated features
#data.drop(['Antal toiletter', 'Ejendomsværdiskat', 'Grundskyld', 'Ejerudgift'], 'columns', inplace=True)
data.drop(['Ejendomsværdiskat', 'Grundskyld'], 'columns', inplace=True)

# %% [markdown]
# ### Linear Regression Model

# %%
y = data['Pris']
data.drop(['Pris'], 'columns', inplace=True)
X = data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

lm = LinearRegression()
lm.fit(X_train, y_train)

coeff_df = pd.DataFrame(lm.coef_, X.columns, columns=['Coefficient'])

# %%
print(coeff_df)
# Out:
#                      Coefficient
# Adresse               -18.810808
# Year build           4739.791153
# Energimærke          3189.594052
# Ejerudgift            914.319641
# Enhedsareal          6058.428745
# Værelser             -951.991086
# Antal toiletter    -29422.433756
# Antal badeværelser  90629.885568
# Ydervæg             -2397.716942
# Tag                    50.441651
# Etager               4285.401479
# Seneste ombygning   -1190.561823
# Varmeinstallation  -79394.518049
# Grundstørrelse       -335.377966

# %%
print('training score')
print(lm.score(X_train, y_train))
# Out:
# training score
# 0.7244938123556085

# %%
print('test score')
print(lm.score(X_test, y_test))
# Out:
# test score
# 0.7379670321412906

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test, predictions)

# %%
sb.displot((y_test-predictions), bins=50)
